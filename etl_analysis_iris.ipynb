# %%
from supabase import create_client
import pandas as pd, os
from dotenv import load_dotenv
load_dotenv()
supabase = create_client(os.getenv("SUPABASE_URL"), os.getenv("SUPABASE_SERVICE_ROLE_KEY"))
data = supabase.table("iris_data").select("*").execute()
df = pd.DataFrame(data.data)
df.head()
df.info()
df.isnull().sum()
df.describe()
df.columns
# Out:
# ---------------------------------------------------------------------------
# SupabaseException                         Traceback (most recent call last)
# Cell In[1], line 5
#       3 from dotenv import load_dotenv
#       4 load_dotenv()
# ----> 5 supabase = create_client(os.getenv("SUPABASE_URL"), os.getenv("SUPABASE_KEY"))
#       6 data = supabase.table("iris_data").select("*").execute()
#       7 df = pd.DataFrame(data.data)
#
# File /opt/anaconda3/lib/python3.13/site-packages/supabase/_sync/client.py:371, in create_client(supabase_url, supabase_key, options)
#     340 def create_client(
#     341     supabase_url: str,
#     342     supabase_key: str,
#     343     options: Optional[ClientOptions] = None,
#     344 ) -> Client:
#     345     """Create client function to instantiate supabase client like JS runtime.
#     346
#     347     Parameters
#    (...)
#     369     Client
#     370     """
# --> 371     return Client.create(
#     372         supabase_url=supabase_url, supabase_key=supabase_key, options=options
#     373     )
#
# File /opt/anaconda3/lib/python3.13/site-packages/supabase/_sync/client.py:104, in Client.create(cls, supabase_url, supabase_key, options)
#      96 @classmethod
#      97 def create(
#      98     cls,
#    (...)
#     101     options: Optional[ClientOptions] = None,
#     102 ) -> "Client":
#     103     auth_header = options.headers.get("Authorization") if options else None
# --> 104     client = cls(supabase_url, supabase_key, options)
#     106     if auth_header is None:
#     107         try:
#
# File /opt/anaconda3/lib/python3.13/site-packages/supabase/_sync/client.py:58, in Client.__init__(self, supabase_url, supabase_key, options)
#      56     raise SupabaseException("supabase_url is required")
#      57 if not supabase_key:
# ---> 58     raise SupabaseException("supabase_key is required")
#      60 # Check if the url and key are valid
#      61 if not re.match(r"^(https?)://.+", supabase_url):
#
# SupabaseException: supabase_key is required
